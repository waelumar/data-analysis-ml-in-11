# %%
#import all the necessary model libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction import text
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('articles.csv',encoding='latin1')
df=pd.DataFrame(df)
df.head()
# Out:
#                                              Article  \
# 0  Data analysis is the process of inspecting and...
# 1  The performance of a machine learning algorith...
# 2  You must have seen the news divided into categ...
# 3  When there are only two classes in a classific...
# 4  The Multinomial Naive Bayes is one of the vari...
#
#                                                Title
# 0                  Best Books to Learn Data Analysis
# 1         Assumptions of Machine Learning Algorithms
# 2          News Classification with Machine Learning
# 3  Multiclass Classification Algorithms in Machin...
# 4        Multinomial Naive Bayes in Machine Learning

# %%
#filling an empty string on null values
df['Article'] = df['Article'].fillna('')
#turning the data in to an list
articles = df['Article'].tolist()


#using the vectorizer model with english stop words
vectorizer = text.TfidfVectorizer(stop_words='english')

# create an matrix of the given articles
tfidf_matrix = vectorizer.fit_transform(articles)

# find the similarity based on the cosin similarity model
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

#printing the model
def recommend_articles(x):
    return ", ".join(df["Title"].loc[x.argsort()[-5:-1]])    
df["Recommended Articles"] = [recommend_articles(x) for x in cosine_similarities]

df.head()
# Out:
#                                              Article  \
# 0  Data analysis is the process of inspecting and...
# 1  The performance of a machine learning algorith...
# 2  You must have seen the news divided into categ...
# 3  When there are only two classes in a classific...
# 4  The Multinomial Naive Bayes is one of the vari...
#
#                                                Title  \
# 0                  Best Books to Learn Data Analysis
# 1         Assumptions of Machine Learning Algorithms
# 2          News Classification with Machine Learning
# 3  Multiclass Classification Algorithms in Machin...
# 4        Multinomial Naive Bayes in Machine Learning
#
#                                 Recommended Articles
# 0  Introduction to Recommendation Systems, Best B...
# 1  Applications of Deep Learning, Best Books to L...
# 2  Language Detection with Machine Learning, Appl...
# 3  Assumptions of Machine Learning Algorithms, Be...
# 4  Assumptions of Machine Learning Algorithms, Me...

# %%
#summary model

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction import text
from sklearn.metrics.pairwise import cosine_similarity
df = pd.read_csv('articles.csv',encoding='latin1')
df=pd.DataFrame(df)
df.head()
df['Article'] = df['Article'].fillna('')
articles = df['Article'].tolist()
vectorizer = text.TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(articles)
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)
def recommend_articles(x):
    return ", ".join(df["Title"].loc[x.argsort()[-5:-1]])    
df["Recommended Articles"] = [recommend_articles(x) for x in cosine_similarities]

df.head()
# Out:
#                                              Article  \
# 0  Data analysis is the process of inspecting and...
# 1  The performance of a machine learning algorith...
# 2  You must have seen the news divided into categ...
# 3  When there are only two classes in a classific...
# 4  The Multinomial Naive Bayes is one of the vari...
#
#                                                Title  \
# 0                  Best Books to Learn Data Analysis
# 1         Assumptions of Machine Learning Algorithms
# 2          News Classification with Machine Learning
# 3  Multiclass Classification Algorithms in Machin...
# 4        Multinomial Naive Bayes in Machine Learning
#
#                                 Recommended Articles
# 0  Introduction to Recommendation Systems, Best B...
# 1  Applications of Deep Learning, Best Books to L...
# 2  Language Detection with Machine Learning, Appl...
# 3  Assumptions of Machine Learning Algorithms, Be...
# 4  Assumptions of Machine Learning Algorithms, Me...
